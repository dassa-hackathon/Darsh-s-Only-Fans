# %%
import pandas as pd

# %%
pd.set_option('max_columns', 600)

# %%
df = pd.read_csv('../input/cuboulderdassahackathonclassification/training.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.dropna(inplace = True)

# %%
for i in df.UUU:
    try:
        float(i)
    except:
        print(i)
# Out:
# 12;I
# non-B hepatitis virus

# %%
for i in df.UUC:
    try:
        float(i)
    except:
        print(i)
# Out:
# -

# %%
df = df[df.UUC != '-']
df = df[~ (df.UUU == 'non-B hepatitis virus')]

# %%
df = df[~ (df.UUU == 'non-B hepatitis virus')]

# %%
df.UUU = df.UUU.astype('float')
df.UUC = df.UUC.astype('float')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop(['Kingdom', 'DNAtype', 'SpeciesName', 'SpeciesID', 'id'], axis = 1), df.Kingdom, test_size = 0.0000000000000000000001)

# %%
x_train = (x_train - x_train.mean()) / x_train.std()
x_test = (x_test - x_test.mean()) / x_test.std()

# %%
rf = RandomForestClassifier(max_depth = 35, class_weight = "balanced", random_state=4213567)
rf = rf.fit(x_train, y_train)
# rf_preds = rf.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score
print(classification_report(rf_preds, y_test))
y_test.value_counts()

# %%
accuracy_score(rf_preds, y_test)

# %%
# test = pd.read_csv('../input/cuboulderdassahackathonclassification/testing.csv')
# op = pd.DataFrame(columns = ['id', 'Kingdom'])
# op.id = test.id
# test.drop(['SpeciesName', 'SpeciesID', 'id'], axis = 1, inplace = True)
# change_this = test.DNAtype
# test.drop('DNAtype', axis = 1, inplace = True)
# test = (test - test.mean()) / test.std()
# # preds = rf.predict(test)
# # op.Kingdom = preds
# # op.to_csv('submissions.csv')

# %%
# op.Kingdom = preds

# %%
# op.to_csv('submissions.csv', index = False)

# %%
# op.Kingdom.value_counts()
# Out:
# bct    673
# vrl    654
# pln    582
# vrt    478
# inv    210
# mam    112
# phg     35
# rod     30
# pri     23
# arc     13
# Name: Kingdom, dtype: int64

# %%
# # x_train.drop(['SpeciesName', 'DNAtype', 'SpeciesID', 'id'], axis = 1, inplace = True)
# # x_test.drop(['SpeciesName', 'DNAtype', 'SpeciesID', 'id'], axis = 1, inplace = True)

# from imblearn.over_sampling import SMOTE
# from imblearn.under_sampling import NearMiss
# sm = SMOTE()
# x_train_1, y_train_1 = sm.fit_resample(x_train.drop(['SpeciesName', 'DNAtype', 'SpeciesID', 'id'], axis = 1), y_train.ravel())

# %%
# rf = RandomForestClassifier(max_depth = 30)
# rf = rf.fit(x_train, y_train)

# %%
# preds = rf.predict_proba(x_test.drop(['SpeciesName', 'DNAtype', 'SpeciesID', 'id'], axis = 1))

# %%
# preds[0]
# Out:
# array([0.01      , 0.06008403, 0.25664653, 0.01      , 0.        ,
#        0.        , 0.32735032, 0.01      , 0.03      , 0.17060662,
#        0.1253125 ])

# %%
# print(classification_report(preds, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          arc       0.79      0.71      0.75        21
#          bct       0.90      0.94      0.92       442
#          inv       0.75      0.79      0.77       197
#          mam       0.75      0.82      0.78        87
#          phg       0.82      0.67      0.74        46
#          plm       0.00      0.00      0.00         2
#          pln       0.90      0.86      0.88       418
#          pri       0.82      0.67      0.73        27
#          rod       0.64      0.66      0.65        35
#          vrl       0.91      0.90      0.90       450
#          vrt       0.93      0.94      0.94       318
#
#     accuracy                           0.88      2043
#    macro avg       0.75      0.72      0.73      2043
# weighted avg       0.88      0.88      0.88      2043

# %%
# accuracy_score(preds, y_test)
# Out:
# 0.8756730298580518

# %%
from sklearn.neighbors import KNeighborsClassifier
for i in range(1, 20):
    knn = KNeighborsClassifier(n_neighbors = i, weights = 'distance', algorithm = 'brute', metric = 'cosine')
    knn.fit(x_train, y_train)
    knn_preds = knn.predict(x_test)
    print(i, accuracy_score(knn_preds, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27/1665925224.py in <module>
#       3     knn = KNeighborsClassifier(n_neighbors = i, weights = 'distance', algorithm = 'brute', metric = 'cosine')
#       4     knn.fit(x_train, y_train)
# ----> 5     knn_preds = knn.predict(x_test)
#       6     print(i, accuracy_score(knn_preds, y_test))
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     212             Class labels for each data sample.
#     213         """
# --> 214         neigh_dist, neigh_ind = self.kneighbors(X)
#     215         classes_ = self.classes_
#     216         _y = self._y
#
# /opt/conda/lib/python3.7/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     715                 X = _check_precomputed(X)
#     716             else:
# ...

# %%
knn = KNeighborsClassifier(n_neighbors = 2, weights = 'distance', algorithm = 'brute', metric = 'cosine')
knn.fit(x_train, y_train)
# knn_preds = knn.predict(x_test)
# print(i, accuracy_score(knn_preds, y_test))
# Out:
# KNeighborsClassifier(algorithm='brute', metric='cosine', n_neighbors=2,
#                      weights='distance')

# %%
import xgboost as xgb
# df = pd.read_csv('../input/cuboulderdassahackathonclassification/training.csv')
# x_train, x_test, y_train, y_test = train_test_split(df.drop(['Kingdom', 'id', 'SpeciesID', 'SpeciesName'], axis = 1), df.Kingdom, test_size=0.2, random_state=42)

# %%
# x_train = (x_train - x_train.mean()) / x_train.std()
# x_test = (x_test - x_test.mean()) / x_test.std()

# %%
test_XG = [] 
train_XG = []
xgb_classifier = xgb.XGBClassifier(eta = 0.25)
y_train = y_train.replace(rep_string)
xgb_classifier.fit(x_train, y_train)
# xgb_preds = xgb_classifier.predict(x_test)
# train_XG.append(xgb_classifier.score(x_train, y_train))
# test_XG.append(xgb_classifier.score(x_test, y_test)) #test_XG.appen
# train_XG, test_XG
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False, eta=0.25,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.25, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, ...)

# %%
replacement = {value:key for key, value in rep_string.items ()}
xgb_preds = xgb_classifier.predict(test)
xgb_preds = pd.Series(xgb_preds).replace(replacement)
xgb_preds
# Out:
# 0       pln
# 1       vrl
# 2       pln
# 3       pln
# 4       inv
#        ...
# 2805    bct
# 2806    vrt
# 2807    vrl
# 2808    pln
# 2809    bct
# Length: 2810, dtype: object

# %%
knn_preds = knn.predict(test)

# %%
rf_preds = rf.predict(test)

# %%
from statistics import median
count = 0
ensemble_preds = []
for i in range(len(xgb_preds)):
    if rf_preds[i] != knn_preds[i] or knn_preds[i] != xgb_preds[i]:
        ensemble_preds.append(knn_preds[i])
    else:
        ensemble_preds.append(median([knn_preds[i], xgb_preds[i], rf_preds[i]]))

# %%
for i in range(len(change_this)):
    if change_this[i] == 2:
        ensemble_preds[i] = 'pln'

# %%
op.Kingdom = ensemble_preds

# %%
op.to_csv('submissions.csv', index = False)

# %%
# learning_rate_range = np.arange(0.01, 1, 0.05)
# test_XG = [] 
# train_XG = []
# rep_string = {
#     'arc': 0,
#     'bct': 1, 'inv':2, 'mam':3, 'phg':4, 'plm':5, 'pln':6, 'pri':7, 'rod':8, 'vrl':9, 'vrt':10
# }
# y_train = y_train.replace(rep_string)
# y_test = y_test.replace(rep_string)
# for lr in learning_rate_range:
#     print(lr)
#     xgb_classifier = xgb.XGBClassifier(eta = lr, max_depth = 30)
#     xgb_classifier.fit(x_train, y_train)
#     train_XG.append(xgb_classifier.score(x_train, y_train))
#     test_XG.append(xgb_classifier.score(x_test, y_test)) #test_XG.append(
# Out:
# 0.01
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27/925972547.py in <module>
#      11     print(lr)
#      12     xgb_classifier = xgb.XGBClassifier(eta = lr, max_depth = 30)
# ---> 13     xgb_classifier.fit(x_train.drop('DNAtype', axis = 1), y_train)
#      14     train_XG.append(xgb_classifier.score(x_train.drop('DNAtype', axis = 1), y_train))
#      15     test_XG.append(xgb_classifier.score(x_test.drop('DNAtype', axis = 1), y_test)) #test_XG.append(
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 7))
plt.plot(learning_rate_range, train_XG, c='orange', label='Train')
plt.plot(learning_rate_range, test_XG, c='m', label='Test')
plt.xlabel('Learning rate')
plt.xticks(learning_rate_range)
plt.ylabel('Accuracy score')
plt.ylim(0.6, 1)
plt.legend(prop={'size': 12}, loc=3)
plt.title('Accuracy score vs. Learning rate of XGBoost', size=14)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 7))
plt.plot(learning_rate_range, train_XG, c='orange', label='Train')
plt.plot(learning_rate_range, test_XG, c='m', label='Test')
plt.xlabel('Learning rate')
plt.xticks(learning_rate_range)
plt.ylabel('Accuracy score')
plt.ylim(0.6, 1)
plt.legend(prop={'size': 12}, loc=3)
plt.title('Accuracy score vs. Learning rate of XGBoost', size=14)
plt.show()

# %%
df.DNAtype = df.DNAtype.astype('int')

# %%
data = df.drop(['id', 'Kingdom', 'SpeciesID', 'Ncodons', 'SpeciesName'], axis = 1)

# %%
target = df[['DNAtype', 'Kingdom']]

# %%
data.DNAtype.value_counts()
# Out:
# 0     7266
# 1     2235
# 2      631
# 4       36
# 5       17
# 3       12
# 6       10
# 12       4
# 11       2
# 7        1
# 9        1
# Name: DNAtype, dtype: int64

# %%
# knn
for i in range(1, 10):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(data[data.DNAtype < 3].drop('DNAtype', axis = 1), target[target.DNAtype < 3].Kingdom)

# %%
test = pd.read_csv('../input/cuboulderdassahackathonclassification/testing.csv')

# %%
ids = test.id
dna = test.DNAtype
test.drop(['SpeciesID', 'Ncodons', 'SpeciesName', 'id', 'DNAtype'], axis = 1, inplace = True)

# %%
preds = knn.predict(test)

# %%
for i in range(len(preds)):
    if dna[i] > 2:
        preds[i] = 'plm'

# %%
pd.Series(preds).value_counts()
# Out:
# bct    660
# pln    604
# vrl    561
# vrt    446
# inv    221
# mam    148
# rod     42
# phg     40
# pri     36
# plm     29
# arc     23
# dtype: int64

# %%
df.Kingdom.value_counts()
# Out:
# bct    2297
# vrl    2236
# pln    1959
# vrt    1636
# inv    1064
# mam     425
# phg     172
# rod     171
# pri     143
# arc      99
# plm      13
# Name: Kingdom, dtype: int64

# %%
df['model'] = df.Kingdom.apply(lambda x:1 if x in ['bct', 'vrl', 'pln', 'vrt', 'inv'] else 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_27/1531420836.py in <module>
# ----> 1 df['model'] = df.Kingdom.apply(lambda x:1 if x in ['bct', 'vrl', 'pln', 'vrt', 'inv'] else 0)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Kingdom'

# %%
select_model = df.drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName'], axis = 1).model
model_1_target = df[df.model == 1].Kingdom
model_0_target = df[df.model == 0].Kingdom

# %%
df = df.drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'Kingdom', 'model'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27/3232143208.py in <module>
# ----> 1 df = df.drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'Kingdom', 'model'], axis = 1)
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
rf_choose_model = RandomForestClassifier(max_depth = 20)
rf_choose_model.fit(df.drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'Kingdom', 'model'], axis = 1), select_model)
# Out:
# RandomForestClassifier(max_depth=20)

# %%
big_model = KNeighborsClassifier(n_neighbors = 3)
big_model.fit(df[df.model == 1].drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'Kingdom', 'model'], axis = 1), model_1_target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_27/4210283525.py in <module>
#       1 big_model = KNeighborsClassifier(n_neighbors = 3)
# ----> 2 big_model.fit(df[df.model == 1].drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'Kingdom', 'model'], axis = 1), model_1_target)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'model'

# %%
small_model = KNeighborsClassifier(n_neighbors = 3)
small_model.fit(df[df.model == 0].drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName', 'Kingdom', 'model'], axis = 1), model_0_target)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
test = pd.read_csv('../input/cuboulderdassahackathonclassification/testing.csv')
ids = test.id
test.drop(['id', 'DNAtype', 'SpeciesID', 'Ncodons', 'SpeciesName'], axis = 1, inplace = True)

select_models = rf_choose_model.predict(test)

final_preds = []
big_model_prediction = big_model.predict(test)
small_model_prediction = small_model.predict(test)

# %%
for i in range(len(select_models)):
    if select_models[i] == 1:
        final_preds.append(big_model_prediction[i])
    else:
        final_preds.append(small_model_prediction[i])

# %%
op = pd.DataFrame(columns = ['id', 'Kingdom'])
op.id = ids
pd.Series(final_preds).value_counts()
# Out:
# bct    676
# pln    610
# vrl    573
# vrt    482
# inv    258
# mam    122
# rod     32
# pri     27
# phg     25
# arc      5
# dtype: int64

# %%
op.Kingdom = final_preds

# %%
op.to_csv('submission.csv', index = False)

# %%
def preprocess(data):
  # Drop all rows with Ncodons less then 1000
#     data = data[data["Ncodons"] > 1000]
    # #Remove all but the three most common dna types.
    # data = data[data["DNAtype"] == 0 or data["DNAtype"] == 1 or data["DNAtype"] == 2]
#     data = data[data["Kingdom"] != "plm"]
#     y = data["Kingdom"]
    X = data[set(data.columns) - set(["Kingdom"])]
    return X

# %%
x, y = preprocess(df.drop(['id', 'DNAtype', 'SpeciesID', 'SpeciesName'], axis = 1))

# %%
knn = KNeighborsClassifier(n_neighbors = 3).fit(x, y)

# %%
test = pd.read_csv('../input/cuboulderdassahackathonclassification/testing.csv')
x = preprocess(test.drop(['id', 'DNAtype', 'SpeciesID', 'SpeciesName'], axis = 1))

# %%
preds = knn.predict(x)

# %%
op = pd.DataFrame(columns = ['id', 'Kingdom'])

# %%
op.id = test.id

# %%
op.Kingdom = preds

# %%
op.to_csv('submission.csv', index = False)
